# %%
import pandas as pd

# %%
groups1 = pd.read_csv('groups1.csv')
groups1.head()
# Out:
#    group_id                           name  category_id  city_id
# 0      6388         Alternative Health NYC           14    10001
# 1      6510      Alternative Energy Meetup            4    10001
# 2      8458              NYC Animal Rights           26    10001
# 3      8940  The New York City Anime Group           29    10001
# 4     10104             NYC Pit Bull Group           26    10001

# %%
groups2 = pd.read_csv('groups2.csv')
groups2.head()
# Out:
#    group_id                                               name  category_id  \
# 0  18879327                                       BachataMania            5
# 1  18880221  Photoshoot Chicago - Photography and Modeling ...           27
# 2  18880426  Chicago Adult Push / Kick Scooter Group Riding...           31
# 3  18880495                  Chicago International Soccer Club           32
# 4  18880695                   Impact.tech San Francisco Meetup            2
#
#    city_id
# 0    10001
# 1    60601
# 2    60601
# 3    60601
# 4    94101

# %%
categories = pd.read_csv('categories.csv')
categories.head()
# Out:
#    category_id            category_name
# 0            1           Arts & Culture
# 1            3       Cars & Motorcycles
# 2            4  Community & Environment
# 3            5                  Dancing
# 4            6     Education & Learning

# %%
cities = pd.read_csv('cities.csv', dtype={'zip': 'string'})
cities.head()
# Out:
#       id            city state    zip
# 0   7093   West New York    NJ  07093
# 1  10001        New York    NY  10001
# 2  13417  New York Mills    NY  13417
# 3  46312    East Chicago    IN  46312
# 4  56567  New York Mills    MN  56567

# %% [markdown]
# ## Concatenating data sets

# %%
demo1 = pd.DataFrame({"A": [1,2,3], 'B': [4,5,6]})
demo2 = pd.DataFrame({"A": [1,2,3]})

result = pd.concat(objs=[groups1, groups2])

# %%
# Pandas preserves the original index labels from both DataFrame in the concatenation
result.loc[1]
# Out:
#    group_id                                               name  category_id  \
# 1      6510                          Alternative Energy Meetup            4
# 1  18880221  Photoshoot Chicago - Photography and Modeling ...           27
#
#    city_id
# 1    10001
# 1    60601

# %%
result = pd.concat([groups1, groups2], ignore_index=True)
result.loc[1]
# Out:
# group_id                            6510
# name           Alternative Energy Meetup
# category_id                            4
# city_id                            10001
# Name: 1, dtype: object

# %%
result = pd.concat(objs=[groups1, groups2], keys=['G1, G2'])
result
# Out:
#              group_id                                              name  \
# G1, G2 0         6388                            Alternative Health NYC
#        1         6510                         Alternative Energy Meetup
#        2         8458                                 NYC Animal Rights
#        3         8940                     The New York City Anime Group
#        4        10104                                NYC Pit Bull Group
# ...               ...                                               ...
#        7994  18875285  NYC's Physically Fit, Active, & Athletic Singles
#        7995  18876571                   Shambhala Meditation Center NYC
#        7996  18876811                                   Chicago Gophers
#        7997  18877490                NYC Students & Young Entrepreneurs
#        7998  18878056                  NYC Green Bay Packer Fans Meetup
#
#              category_id  city_id
# G1, G2 0              14    10001
#        1               4    10001
#        2              26    10001
#        3              29    10001
#        4              26    10001
# ...                  ...      ...
#        7994           30    10001
#        7995           14    10001
#        7996           34    60601
#        7997            2    10001
#        7998           32    10001
#
# [7999 rows x 4 columns]

# %% [markdown]
# ## Missing values in concatenated DataFrames

# %%
sports_champions_A = pd.DataFrame(
    data=[
        ['New England Patriots', 'Houston Astros'],
        ['Philadelphia Eagless', 'Boston Red Sox'],
    ],
    index=[2017, 2018],
    columns=['Football', 'Baseball']
)

sports_champions_B = pd.DataFrame(
    data=[
        ['New England Patriots', 'St. Louis Blues'],
        ['Kansas City Chiefs', 'Tampa Bay Lightning'],
    ],
    index=[2019, 2020],
    columns=['Football', 'Hockey']
)

# %%
pd.concat([sports_champions_A, sports_champions_B])
# Out:
#                   Football        Baseball               Hockey
# 2017  New England Patriots  Houston Astros                  NaN
# 2018  Philadelphia Eagless  Boston Red Sox                  NaN
# 2019  New England Patriots             NaN      St. Louis Blues
# 2020    Kansas City Chiefs             NaN  Tampa Bay Lightning

# %%
sports_champions_C = pd.DataFrame(
             data = [
                 ["Pittsburgh Penguins", "Golden State Warriors"],
                 ["Washington Capitals", "Golden State Warriors"]
         ],
             columns = ["Hockey", "Basketball"],
             index = [2017, 2018]
         )
 
sports_champions_C
# Out:
#                    Hockey             Basketball
# 2017  Pittsburgh Penguins  Golden State Warriors
# 2018  Washington Capitals  Golden State Warriors

# %%
pd.concat([sports_champions_A, sports_champions_C])
# Out:
#                   Football        Baseball               Hockey  \
# 2017  New England Patriots  Houston Astros                  NaN
# 2018  Philadelphia Eagless  Boston Red Sox                  NaN
# 2017                   NaN             NaN  Pittsburgh Penguins
# 2018                   NaN             NaN  Washington Capitals
#
#                  Basketball
# 2017                    NaN
# 2018                    NaN
# 2017  Golden State Warriors
# 2018  Golden State Warriors

# %%
pd.concat(objs=[sports_champions_A, sports_champions_C], axis=1)
# Out:
#                   Football        Baseball               Hockey  \
# 2017  New England Patriots  Houston Astros  Pittsburgh Penguins
# 2018  Philadelphia Eagless  Boston Red Sox  Washington Capitals
#
#                  Basketball
# 2017  Golden State Warriors
# 2018  Golden State Warriors

# %% [markdown]
# ## Left joins

# %%
groups1.head()
# Out:
#    group_id                           name  category_id  city_id
# 0      6388         Alternative Health NYC           14    10001
# 1      6510      Alternative Energy Meetup            4    10001
# 2      8458              NYC Animal Rights           26    10001
# 3      8940  The New York City Anime Group           29    10001
# 4     10104             NYC Pit Bull Group           26    10001

# %%
categories.head()
# Out:
#    category_id            category_name
# 0            1           Arts & Culture
# 1            3       Cars & Motorcycles
# 2            4  Community & Environment
# 3            5                  Dancing
# 4            6     Education & Learning

# %%
groups1.merge(categories, how='left', on='category_id').head()
# Out:
#    group_id                           name  category_id  city_id  \
# 0      6388         Alternative Health NYC           14    10001
# 1      6510      Alternative Energy Meetup            4    10001
# 2      8458              NYC Animal Rights           26    10001
# 3      8940  The New York City Anime Group           29    10001
# 4     10104             NYC Pit Bull Group           26    10001
#
#              category_name
# 0       Health & Wellbeing
# 1  Community & Environment
# 2                      NaN
# 3         Sci-Fi & Fantasy
# 4                      NaN

# %% [markdown]
# ## Inner joins

# %%
groups1.merge(categories, how='inner', on = 'category_id').head()
# Out:
#    group_id                                    name  category_id  city_id  \
# 0      6388                  Alternative Health NYC           14    10001
# 1     54126                      Energy Healers NYC           14    10001
# 2     67776                 Flourishing Life Meetup           14    10001
# 3    111855  Hypnosis & NLP NYC - Update Your Brain           14    10001
# 4    129277         The Live Food Chicago Community           14    60601
#
#         category_name
# 0  Health & Wellbeing
# 1  Health & Wellbeing
# 2  Health & Wellbeing
# 3  Health & Wellbeing
# 4  Health & Wellbeing

# %% [markdown]
# ## Outer joins
#
# An outer join combines all records across two data sets. Exclusivity does not matter with an outer join. Figure 10.3 shows the results of an outer join; pandas includes all values irrespective of whether they belong in one data set or both data sets.

# %%
cities.head()
# Out:
#       id            city state    zip
# 0   7093   West New York    NJ  07093
# 1  10001        New York    NY  10001
# 2  13417  New York Mills    NY  13417
# 3  46312    East Chicago    IN  46312
# 4  56567  New York Mills    MN  56567

# %%
groups2
# Out:
#       group_id                                               name  \
# 0     18879327                                       BachataMania
# 1     18880221  Photoshoot Chicago - Photography and Modeling ...
# 2     18880426  Chicago Adult Push / Kick Scooter Group Riding...
# 3     18880495                  Chicago International Soccer Club
# 4     18880695                   Impact.tech San Francisco Meetup
# ...        ...                                                ...
# 8326  26377464                                            Shinect
# 8327  26377698  The art of getting what you want [conference s...
# 8328  26378067                        Streeterville Running Group
# 8329  26378128                                     Just Dance NYC
# 8330  26378470           FREE Arabic Chicago Evanston North Burbs
#
#       category_id  city_id
# 0               5    10001
# 1              27    60601
# 2              31    60601
# 3              32    60601
# 4               2    94101
# ...           ...      ...
# 8326           34    94101
# 8327           14    94101
# 8328            9    60601
# 8329           23    10001
# 8330           31    60601
#
# [8331 rows x 4 columns]

# %%
groups1.merge(cities, left_on="city_id", right_on="id", how="outer")
# Out:
#       group_id                           name  category_id  city_id     id  \
# 0       6388.0         Alternative Health NYC         14.0  10001.0  10001
# 1       6510.0      Alternative Energy Meetup          4.0  10001.0  10001
# 2       8458.0              NYC Animal Rights         26.0  10001.0  10001
# 3       8940.0  The New York City Anime Group         29.0  10001.0  10001
# 4      10104.0             NYC Pit Bull Group         26.0  10001.0  10001
# ...        ...                            ...          ...      ...    ...
# 8000       NaN                            NaN          NaN      NaN  13417
# 8001       NaN                            NaN          NaN      NaN  46312
# 8002       NaN                            NaN          NaN      NaN  56567
# 8003       NaN                            NaN          NaN      NaN  60064
# 8004       NaN                            NaN          NaN      NaN  95712
#
#                 city state    zip
# 0           New York    NY  10001
# 1           New York    NY  10001
# 2           New York    NY  10001
# 3           New York    NY  10001
# 4           New York    NY  10001
# ...              ...   ...    ...
# 8000  New York Mills    NY  13417
# 8001    East Chicago    IN  46312
# 8002  New York Mills    MN  56567
# 8003   North Chicago    IL  60064
# 8004    Chicago Park    CA  95712
#
# [8005 rows x 8 columns]

# %% [markdown]
# ## Merging on index labels

# %%
cities = cities.set_index('id')

# %%
cities.head()
# Out:
#                  city state    zip
# id
# 7093    West New York    NJ  07093
# 10001        New York    NY  10001
# 13417  New York Mills    NY  13417
# 46312    East Chicago    IN  46312
# 56567  New York Mills    MN  56567

# %%
groups1.merge(cities, left_on='city_id', right_index=True, how="left")
# Out:
#       group_id                                              name  category_id  \
# 0         6388                            Alternative Health NYC           14
# 1         6510                         Alternative Energy Meetup            4
# 2         8458                                 NYC Animal Rights           26
# 3         8940                     The New York City Anime Group           29
# 4        10104                                NYC Pit Bull Group           26
# ...        ...                                               ...          ...
# 7994  18875285  NYC's Physically Fit, Active, & Athletic Singles           30
# 7995  18876571                   Shambhala Meditation Center NYC           14
# 7996  18876811                                   Chicago Gophers           34
# 7997  18877490                NYC Students & Young Entrepreneurs            2
# 7998  18878056                  NYC Green Bay Packer Fans Meetup           32
#
#       city_id      city state    zip
# 0       10001  New York    NY  10001
# 1       10001  New York    NY  10001
# 2       10001  New York    NY  10001
# 3       10001  New York    NY  10001
# 4       10001  New York    NY  10001
# ...       ...       ...   ...    ...
# 7994    10001  New York    NY  10001
# 7995    10001  New York    NY  10001
# 7996    60601   Chicago    IL  60290
# 7997    10001  New York    NY  10001
# 7998    10001  New York    NY  10001
#
# [7999 rows x 7 columns]

# %%
groups1
# Out:
#       group_id                                              name  category_id  \
# 0         6388                            Alternative Health NYC           14
# 1         6510                         Alternative Energy Meetup            4
# 2         8458                                 NYC Animal Rights           26
# 3         8940                     The New York City Anime Group           29
# 4        10104                                NYC Pit Bull Group           26
# ...        ...                                               ...          ...
# 7994  18875285  NYC's Physically Fit, Active, & Athletic Singles           30
# 7995  18876571                   Shambhala Meditation Center NYC           14
# 7996  18876811                                   Chicago Gophers           34
# 7997  18877490                NYC Students & Young Entrepreneurs            2
# 7998  18878056                  NYC Green Bay Packer Fans Meetup           32
#
#       city_id
# 0       10001
# 1       10001
# 2       10001
# 3       10001
# 4       10001
# ...       ...
# 7994    10001
# 7995    10001
# 7996    60601
# 7997    10001
# 7998    10001
#
# [7999 rows x 4 columns]

# %%
df = pd.read_csv('Wholesale customers data.csv')
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
df['Region'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df['Channel'].unique()
# Out:
# array([2, 1], dtype=int64)
